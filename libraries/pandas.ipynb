# %%
import pandas as pd

# %%
data={'Name':['Alice','Bob'],'Age':[25,30]}
df=pd.DataFrame(data)
print(df)
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
lst=[['Alice',25],['Bob',30]]
df=pd.DataFrame(lst,columns=['Name','Age'])
print(df)
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.head()
df.tail()
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    2 non-null      str
#  1   Age     2 non-null      int64
# dtypes: int64(1), str(1)
# memory usage: 172.0 bytes
#              Age
# count   2.000000
# mean   27.500000
# std     3.535534
# min    25.000000
# 25%    26.250000
# 50%    27.500000
# 75%    28.750000
# max    30.000000

# %%
df['Name']
# Out:
# 0    Alice
# 1      Bob
# Name: Name, dtype: str

# %%
df['Age']
# Out:
# 0    25
# 1    30
# Name: Age, dtype: int64

# %%
df[['Name','Age']]
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.loc[0]
# Out:
# Name    Alice
# Age        25
# Name: 0, dtype: object

# %%
df.iloc[1,0]
# Out:
# 'Bob'

# %%
df[df['Age']>25]
# Out:
#   Name  Age
# 1  Bob   30

# %%
df['Gender']=['F','M']
df
# Out:
#     Name  Age Gender
# 0  Alice   25      F
# 1    Bob   30      M

# %%
df.drop('Age',axis=1,inplace=True)

# %%
df
# Out:
#     Name Gender
# 0  Alice      F
# 1    Bob      M

# %%
df.isnull()
# Out:
#     Name  Gender
# 0  False    True
# 1  False   False

# %%
df.dropna()
# Out:
#   Name Gender
# 1  Bob      M

# %%
df.fillna(0)
# Out:
#     Name Gender
# 0  Alice      0
# 1    Bob      M

# %%
df.loc[2]=['Kuttu','M']

# %%
df.loc[3]=['Amal',None]

# %%
df['Age']=[25,30,35,40]

# %%
df.groupby('Gender')['Age'].mean()
# Out:
# Gender
# F    25.0
# M    32.5
# Name: Age, dtype: float64

# %%
data2=[[1001,'ECE',1],[1002,'CIVIL',2]]
df2=pd.DataFrame(data2,columns=['DeptID','DeptName','key'])

# %%
df['key']=[1,2,1,2]
df
# Out:
#     Name Gender  Age  key
# 0  Alice      F   25    1
# 1    Bob      M   30    2
# 2  Kuttu      M   35    1
# 3   Amal    NaN   40    2

# %%
pd.merge(df,df2,on='key')
# Out:
#     Name Gender  Age  key  DeptID DeptName
# 0  Alice      F   25    1    1001      ECE
# 1    Bob      M   30    2    1002    CIVIL
# 2  Kuttu      M   35    1    1001      ECE
# 3   Amal    NaN   40    2    1002    CIVIL

# %%
df1 = df.set_index("key")
df2 = df2.set_index("key")
df1.join(df2)
# Out:
#       Name Gender  Age  DeptID DeptName
# key
# 1    Alice      F   25    1001      ECE
# 2      Bob      M   30    1002    CIVIL
# 1    Kuttu      M   35    1001      ECE
# 2     Amal    NaN   40    1002    CIVIL

# %%
df.to_csv('output.csv',index=False)

# %%
df3=pd.read_csv('libraries/employee.csv')
# Out:
#    Name  Age Gender
# 0   Aby   25      M
# 1  Biby   35      M
# 2  Siby   32      M
# 3  Tiby   27      M

# %%
df3.sort_values('Age')
# Out:
#    Name  Age Gender
# 0   Aby   25      M
# 3  Tiby   27      M
# 2  Siby   32      M
# 1  Biby   35      M

# %%
df['Age'].apply(lambda x:x+1)
# Out:
# 0    26
# 1    31
# 2    36
# 3    41
# Name: Age, dtype: int64

# %%
df['Name'].unique()
# Out:
# <ArrowStringArray>
# ['Alice', 'Bob', 'Kuttu', 'Amal']
# Length: 4, dtype: str

# %%
df['Age'].value_counts()
# Out:
# Age
# 25    1
# 30    1
# 35    1
# 40    1
# Name: count, dtype: int64
